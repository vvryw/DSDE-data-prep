# %%
from bs4 import BeautifulSoup
import pandas as pd

# %%
html = """<ul class="select2-results__options" role="listbox" aria-multiselectable="true" id="select2-MeasIndex-results" aria-expanded="true" aria-hidden="false"><li class="select2-results__option select2-results__option--selectable select2-results__option--selected select2-results__option--highlighted" id="select2-MeasIndex-result-16bk-83" role="option" data-select2-id="select2-data-select2-MeasIndex-result-16bk-83" aria-selected="true">เขตคลองสาน</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-x1n1-101" role="option" data-select2-id="select2-data-select2-MeasIndex-result-x1n1-101" aria-selected="false">เขตคลองสามวา</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-4q1q-94" role="option" data-select2-id="select2-data-select2-MeasIndex-result-4q1q-94" aria-selected="false">เขตคลองเตย</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-k0ak-77" role="option" data-select2-id="select2-data-select2-MeasIndex-result-k0ak-77" aria-selected="false">เขตคันนายาว</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-mrkj-73" role="option" data-select2-id="select2-data-select2-MeasIndex-result-mrkj-73" aria-selected="false">เขตจตุจักร</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-7k8f-102" role="option" data-select2-id="select2-data-select2-MeasIndex-result-7k8f-102" aria-selected="false">เขตจอมทอง</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-k25c-74" role="option" data-select2-id="select2-data-select2-MeasIndex-result-k25c-74" aria-selected="false">เขตดอนเมือง</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-665n-56" role="option" data-select2-id="select2-data-select2-MeasIndex-result-665n-56" aria-selected="false">เขตดินแดง</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-4edp-60" role="option" data-select2-id="select2-data-select2-MeasIndex-result-4edp-60" aria-selected="false">เขตดุสิต</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-1i5t-86" role="option" data-select2-id="select2-data-select2-MeasIndex-result-1i5t-86" aria-selected="false">เขตตลิ่งชัน</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-br4b-87" role="option" data-select2-id="select2-data-select2-MeasIndex-result-br4b-87" aria-selected="false">เขตทวีวัฒนา</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-tgbd-91" role="option" data-select2-id="select2-data-select2-MeasIndex-result-tgbd-91" aria-selected="false">เขตทุ่งครุ</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-i2fp-82" role="option" data-select2-id="select2-data-select2-MeasIndex-result-i2fp-82" aria-selected="false">เขตธนบุรี</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-yeqf-85" role="option" data-select2-id="select2-data-select2-MeasIndex-result-yeqf-85" aria-selected="false">เขตบางกอกน้อย</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-zhsy-84" role="option" data-select2-id="select2-data-select2-MeasIndex-result-zhsy-84" aria-selected="false">เขตบางกอกใหญ่</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-bb7e-76" role="option" data-select2-id="select2-data-select2-MeasIndex-result-bb7e-76" aria-selected="false">เขตบางกะปิ</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-wsc4-105" role="option" data-select2-id="select2-data-select2-MeasIndex-result-wsc4-105" aria-selected="false">เขตบางขุนเทียน</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-du9x-95" role="option" data-select2-id="select2-data-select2-MeasIndex-result-du9x-95" aria-selected="false">เขตบางซื่อ</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-8iq6-72" role="option" data-select2-id="select2-data-select2-MeasIndex-result-8iq6-72" aria-selected="false">เขตบางนา</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-gp8e-90" role="option" data-select2-id="select2-data-select2-MeasIndex-result-gp8e-90" aria-selected="false">เขตบางบอน</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-kpy0-103" role="option" data-select2-id="select2-data-select2-MeasIndex-result-kpy0-103" aria-selected="false">เขตบางพลัด</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-r814-66" role="option" data-select2-id="select2-data-select2-MeasIndex-result-r814-66" aria-selected="false">เขตบางรัก</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-grrr-98" role="option" data-select2-id="select2-data-select2-MeasIndex-result-grrr-98" aria-selected="false">เขตบางเขน</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-sqam-104" role="option" data-select2-id="select2-data-select2-MeasIndex-result-sqam-104" aria-selected="false">เขตบางแค</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-m6or-100" role="option" data-select2-id="select2-data-select2-MeasIndex-result-m6or-100" aria-selected="false">เขตบึงกุ่ม</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-b7t5-65" role="option" data-select2-id="select2-data-select2-MeasIndex-result-b7t5-65" aria-selected="false">เขตปทุมวัน</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-mqme-81" role="option" data-select2-id="select2-data-select2-MeasIndex-result-mqme-81" aria-selected="false">เขตประเวศ</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-s9ow-61" role="option" data-select2-id="select2-data-select2-MeasIndex-result-s9ow-61" aria-selected="false">เขตป้อมปราบศัตรูพ่าย</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-flev-63" role="option" data-select2-id="select2-data-select2-MeasIndex-result-flev-63" aria-selected="false">เขตพญาไท</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-jkwr-92" role="option" data-select2-id="select2-data-select2-MeasIndex-result-jkwr-92" aria-selected="false">เขตพระนคร</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-2rk7-57" role="option" data-select2-id="select2-data-select2-MeasIndex-result-2rk7-57" aria-selected="false">เขตพระโขนง</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-uxxt-88" role="option" data-select2-id="select2-data-select2-MeasIndex-result-uxxt-88" aria-selected="false">เขตภาษีเจริญ</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-y6pd-79" role="option" data-select2-id="select2-data-select2-MeasIndex-result-y6pd-79" aria-selected="false">เขตมีนบุรี</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-m5y7-69" role="option" data-select2-id="select2-data-select2-MeasIndex-result-m5y7-69" aria-selected="false">เขตยานนาวา</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-lf49-59" role="option" data-select2-id="select2-data-select2-MeasIndex-result-lf49-59" aria-selected="false">เขตราชเทวี</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-3uk6-58" role="option" data-select2-id="select2-data-select2-MeasIndex-result-3uk6-58" aria-selected="false">เขตราษฎร์บูรณะ</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-857x-78" role="option" data-select2-id="select2-data-select2-MeasIndex-result-857x-78" aria-selected="false">เขตลาดกระบัง</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-qtgn-96" role="option" data-select2-id="select2-data-select2-MeasIndex-result-qtgn-96" aria-selected="false">เขตลาดพร้าว</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-ke4r-64" role="option" data-select2-id="select2-data-select2-MeasIndex-result-ke4r-64" aria-selected="false">เขตวังทองหลาง</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-qvkh-70" role="option" data-select2-id="select2-data-select2-MeasIndex-result-qvkh-70" aria-selected="false">เขตวัฒนา</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-9q3c-71" role="option" data-select2-id="select2-data-select2-MeasIndex-result-9q3c-71" aria-selected="false">เขตสวนหลวง</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-xgnr-99" role="option" data-select2-id="select2-data-select2-MeasIndex-result-xgnr-99" aria-selected="false">เขตสะพานสูง</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-vwev-62" role="option" data-select2-id="select2-data-select2-MeasIndex-result-vwev-62" aria-selected="false">เขตสัมพันธวงศ์</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-xnmm-67" role="option" data-select2-id="select2-data-select2-MeasIndex-result-xnmm-67" aria-selected="false">เขตสาทร</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-xju7-75" role="option" data-select2-id="select2-data-select2-MeasIndex-result-xju7-75" aria-selected="false">เขตสายไหม</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-io8x-80" role="option" data-select2-id="select2-data-select2-MeasIndex-result-io8x-80" aria-selected="false">เขตหนองจอก</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-rob1-89" role="option" data-select2-id="select2-data-select2-MeasIndex-result-rob1-89" aria-selected="false">เขตหนองแขม</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-yxz1-97" role="option" data-select2-id="select2-data-select2-MeasIndex-result-yxz1-97" aria-selected="false">เขตหลักสี่</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-9q2u-93" role="option" data-select2-id="select2-data-select2-MeasIndex-result-9q2u-93" aria-selected="false">เขตห้วยขวาง</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-95pc-118" role="option" data-select2-id="select2-data-select2-MeasIndex-result-95pc-118" aria-selected="false">สวน 60 พรรษาสมเด็จพระนางเจ้าพระบรมราชินีนาถ เขตลาดกระบัง</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-c3w2-130" role="option" data-select2-id="select2-data-select2-MeasIndex-result-c3w2-130" aria-selected="false">สวนกีฬารามอินทรา เขตบางเขน</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-gwbu-116" role="option" data-select2-id="select2-data-select2-MeasIndex-result-gwbu-116" aria-selected="false">สวนจตุจักร เขตจตุจักร</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-dspj-127" role="option" data-select2-id="select2-data-select2-MeasIndex-result-dspj-127" aria-selected="false">สวนทวีวนารมย์ เขตทวีวัฒนา</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-mgwy-121" role="option" data-select2-id="select2-data-select2-MeasIndex-result-mgwy-121" aria-selected="false">สวนธนบุรีรมย์ เขตทุ่งครุ</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-5jh0-126" role="option" data-select2-id="select2-data-select2-MeasIndex-result-5jh0-126" aria-selected="false">สวนบางแคภิรมย์ เขตบางแค</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-4nrk-128" role="option" data-select2-id="select2-data-select2-MeasIndex-result-4nrk-128" aria-selected="false">สวนพระนคร เขตลาดกระบัง</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-gtps-120" role="option" data-select2-id="select2-data-select2-MeasIndex-result-gtps-120" aria-selected="false">สวนรมณีย์ทุ่งสีกัน เขตดอนเมือง</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-fqei-114" role="option" data-select2-id="select2-data-select2-MeasIndex-result-fqei-114" aria-selected="false">สวนลุมพินี เขตปทุมวัน</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-nij6-115" role="option" data-select2-id="select2-data-select2-MeasIndex-result-nij6-115" aria-selected="false">สวนวชิรเบญจทัศ เขตจตุจักร</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-kxp3-123" role="option" data-select2-id="select2-data-select2-MeasIndex-result-kxp3-123" aria-selected="false">สวนสมเด็จพระนางเจ้าสิริกิติ์ฯ เขตจตุจักร</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-uh7u-132" role="option" data-select2-id="select2-data-select2-MeasIndex-result-uh7u-132" aria-selected="false">สวนสันติภาพ เขตราชเทวี</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-r402-131" role="option" data-select2-id="select2-data-select2-MeasIndex-result-r402-131" aria-selected="false">สวนสาธารณะเฉลิมพระเกียรติ 6 รอบพระชนมพรรษา เขตบางคอแหลม</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-ttlk-129" role="option" data-select2-id="select2-data-select2-MeasIndex-result-ttlk-129" aria-selected="false">สวนหนองจอก เขตหนองจอก</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-0y1p-117" role="option" data-select2-id="select2-data-select2-MeasIndex-result-0y1p-117" aria-selected="false">สวนหลวง ร.9 เขตประเวศ</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-ca4l-133" role="option" data-select2-id="select2-data-select2-MeasIndex-result-ca4l-133" aria-selected="false">สวนหลวงพระราม 8 เขตบางพลัด</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-e92k-124" role="option" data-select2-id="select2-data-select2-MeasIndex-result-e92k-124" aria-selected="false">สวนเฉลิมพระเกียรติ 80 พรรษา เขตบางกอกน้อย</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-8mi0-122" role="option" data-select2-id="select2-data-select2-MeasIndex-result-8mi0-122" aria-selected="false">สวนเบญจกิติ เขตคลองเตย</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-0v07-125" role="option" data-select2-id="select2-data-select2-MeasIndex-result-0v07-125" aria-selected="false">สวนเสรีไทย เขตบึงกุ่ม</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-f1mb-119" role="option" data-select2-id="select2-data-select2-MeasIndex-result-f1mb-119" aria-selected="false">อุทยานเบญจสิริ เขตคลองเตย</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-ntxr-134" role="option" data-select2-id="select2-data-select2-MeasIndex-result-ntxr-134" aria-selected="false">เขตดินแดง (สถานี คพ.)</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-j8wa-135" role="option" data-select2-id="select2-data-select2-MeasIndex-result-j8wa-135" aria-selected="false">เขตดินแดง (สถานี คพ.)</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-eg74-143" role="option" data-select2-id="select2-data-select2-MeasIndex-result-eg74-143" aria-selected="false">เขตธนบุรี (สถานี คพ.)</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-72vl-144" role="option" data-select2-id="select2-data-select2-MeasIndex-result-72vl-144" aria-selected="false">เขตธนบุรี (สถานี คพ.)</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-279b-142" role="option" data-select2-id="select2-data-select2-MeasIndex-result-279b-142" aria-selected="false">เขตบางกะปิ (สถานี คพ.)</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-yjvi-145" role="option" data-select2-id="select2-data-select2-MeasIndex-result-yjvi-145" aria-selected="false">เขตบางขุนเทียน (สถานี คพ.)</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-lfas-112" role="option" data-select2-id="select2-data-select2-MeasIndex-result-lfas-112" aria-selected="false">เขตบางคอแหลม เคลื่อนที่(3)</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-g4g5-141" role="option" data-select2-id="select2-data-select2-MeasIndex-result-g4g5-141" aria-selected="false">เขตบางนา (สถานี คพ.)</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-vrfd-139" role="option" data-select2-id="select2-data-select2-MeasIndex-result-vrfd-139" aria-selected="false">เขตปทุมวัน (สถานี คพ.)</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-k456-136" role="option" data-select2-id="select2-data-select2-MeasIndex-result-k456-136" aria-selected="false">เขตพญาไท (สถานี คพ.)</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-i1ux-140" role="option" data-select2-id="select2-data-select2-MeasIndex-result-i1ux-140" aria-selected="false">เขตยานนาวา (สถานี คพ.)</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-pdfb-137" role="option" data-select2-id="select2-data-select2-MeasIndex-result-pdfb-137" aria-selected="false">เขตวังทองหลาง (สถานี คพ.)</li><li class="select2-results__option select2-results__option--selectable" id="select2-MeasIndex-result-hqu6-138" role="option" data-select2-id="select2-data-select2-MeasIndex-result-hqu6-138" aria-selected="false">เขตวังทองหลาง (สถานี คพ.)</li></ul>"""

# %%
soup = BeautifulSoup(html, "html.parser")

pairs = []

for li in soup.find_all("li", class_="select2-results__option"):
    text = li.get_text(strip=True)
    raw_id = li.get("id")

    # extract the number at the end of the id
    id_number = raw_id.split("-")[-1]

    # remove the word "เขต" if exists
    text_clean = text.replace("เขต", "").strip()

    pairs.append((id_number, text_clean))

# print result
print('total pair:', len(pairs))
for p in pairs:
    print(p)
# Out:
# total pair: 82
# ('83', 'คลองสาน')
# ('101', 'คลองสามวา')
# ('94', 'คลองเตย')
# ('77', 'คันนายาว')
# ('73', 'จตุจักร')
# ('102', 'จอมทอง')
# ('74', 'ดอนเมือง')
# ('56', 'ดินแดง')
# ('60', 'ดุสิต')
# ('86', 'ตลิ่งชัน')
# ('87', 'ทวีวัฒนา')
# ('91', 'ทุ่งครุ')
# ('82', 'ธนบุรี')
# ('85', 'บางกอกน้อย')
# ('84', 'บางกอกใหญ่')
# ('76', 'บางกะปิ')
# ('105', 'บางขุนเทียน')
# ('95', 'บางซื่อ')
# ('72', 'บางนา')
# ('90', 'บางบอน')
# ('103', 'บางพลัด')
# ('66', 'บางรัก')
# ('98', 'บางเขน')
# ('104', 'บางแค')
# ('100', 'บึงกุ่ม')
# ('65', 'ปทุมวัน')
# ('81', 'ประเวศ')
# ('61', 'ป้อมปราบศัตรูพ่าย')
# ('63', 'พญาไท')
# ('92', 'พระนคร')
# ('57', 'พระโขนง')
# ('88', 'ภาษีเจริญ')
# ('79', 'มีนบุรี')
# ('69', 'ยานนาวา')
# ('59', 'ราชเทวี')
# ('58', 'ราษฎร์บูรณะ')
# ('78', 'ลาดกระบัง')
# ('96', 'ลาดพร้าว')
# ('64', 'วังทองหลาง')
# ('70', 'วัฒนา')
# ('71', 'สวนหลวง')
# ('99', 'สะพานสูง')
# ('62', 'สัมพันธวงศ์')
# ('67', 'สาทร')
# ('75', 'สายไหม')
# ('80', 'หนองจอก')
# ('89', 'หนองแขม')
# ...

# %%
# pairs = [(id_number, text_clean), ...]   # ← from your previous code

df_out = pd.DataFrame(pairs, columns=["id", "name"])

df_out.to_csv("district_mapping.csv", index=False, encoding="utf-8-sig")

print("Saved as district_mapping.csv")
# Out:
# Saved as district_mapping.csv
